# %%
# !pip install -q streamlit transformers torch pymongo sqlalchemy
# !npm install -g localtunnel
# Out:
# ⠙⠹⠸⠼⠴⠦
# up to date, audited 23 packages in 743ms
# ⠦
# ⠦3 packages are looking for funding
# ⠦  run `npm fund` for details
# ⠦
# 2 high severity vulnerabilities
#
# To address all issues (including breaking changes), run:
#   npm audit fix --force
#
# Run `npm audit` for details.
# ⠦

# %%
import urllib
print("Password/Endpoint IP for localtunnel is:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))
# Out:
# Password/Endpoint IP for localtunnel is: 35.198.237.247

# %%
# !streamlit run /content/drive/MyDrive/NoNoQL/app_colab.py --server.port 8501 --server.headless true --server.enableCORS false --server.enableXsrfProtection false &>/content/logs.txt &
# !npx localtunnel --port 8501
# Out:
# ⠙your url is: https://legal-areas-cough.loca.lt
